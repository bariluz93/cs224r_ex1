# %%
# !ls
# Out:
# colab_instructions.md  cs224r_ex1.ipynb  README.md	   setup.py
# cs224r		       installation.md	 requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/cs224r_ex1
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for cs224r
# ...
